# %% [markdown]
# # **Cluster South Mumbai**

# %% [markdown]
# # **Iteration # : 7**

# %% [markdown]
# # **Version 9**

# %% [markdown]
# # **Two key changes in approach**
# ## Decided to give weight to categories based on their importance to
# ## visitors and rarity.
# ## Similar Categories merged.
# ## Wrong categories corrected.

# %% [markdown]
# ## Version 8 : for all Mumbai : Removed aksa.
# ## Fixed Issue : borough all coming as South Mumbai
# ## Requires code cleanup : Done.

# %% [markdown]
# ## **Add new boroughs**

# %% [markdown]
# #### In this analysis, the focus was South Mumbai, which is precisely area for foreign tourists. It is full of restaurants,hotelsand other places of entertainment.
# ### But upon complete analysis we noticed that most of the areas fall under single cluster. This can be due to Indian Restaurant.

# %% [markdown]
# #### Therefore, I decided to do a second iteration,by increasing number of clusters to 10 and see if clustering looks Okay.

# %% [markdown]
# Later a third iteration can be tried by discarding Indian restuarant and see how clusters change.

# %% [markdown]
# ### A fourth iteration can be done with hybrid approach ie by discarding Indian Restaurant and increasing number of clusters at the same time.

# %% [markdown]
# #### A sixth iteration can be done by increasing number of areas from other parts of the city as well. It seems that entire South Mumbai by and large has similar charactersitics.

# %% [markdown]
# ### A fifth iteration can be done by increasing radius to 900 m.

# %% [markdown]
# ### Seventh iteration : Another question we may resolve is by comparing two different boroughs of Mumbai say South Mumbai and North Mumbai. How similar and how different they are.

# %% [markdown]
# #### By increasing radius, lot of overlappring of nearby neighborhood happened, and many duplicate venues appeared. These duplicates can be eliminated.

# %% [markdown]
# **Library**

# %% [markdown]
# ### So, Let's begin second iteration.

# %%
import pandas as pd
from pandas.io.json import json_normalize  # tranform JSON file into a pandas dataframe

import numpy as np

from bs4 import BeautifulSoup

# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

import seaborn as sns
from urllib.request import urlopen

import requests
# import k-means from clustering stage
from sklearn.cluster import KMeans

print("Library imported 111.")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Library imported 111.

# %%
import folium # map rendering library
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
print("Library imported 112.")
# Out:
# Library imported 112.

# %%
areas_south = ["Colaba","Apollo Bandar","Fort","Churchgate","Nariman Point" \
        ,"Marine Lines","Walkeshwar","Malabar Hill","Kalbadevi","Bhuleshwar" \
        ,"Masjid Bandar","Darukhana","Pydhoni","Nagpada","Dongri" \
        ,"Byculla","Grand Road","Mazgaon","Mumbai Central","Mahalaxmi" \
        ,"Worli"]
#areas_south

# %%
areas_west = ["Dadar","Bandra West","Juhu","Andheri","Kalina" \
              ,"Santa Cruz","Mahim","Khar"]
        
#areas_west

# %%
areas_east = ["Kurla","Ghatkopar","Chembur","Govandi","Mulund West"] 
areas_east
# Out:
# ['Kurla', 'Ghatkopar', 'Chembur', 'Govandi', 'Mulund West']

# %%
areas_north = ["Powai","Jogeshwari","Malad","Borivali","Mira Road"] 
areas_north
# Out:
# ['Powai', 'Jogeshwari', 'Malad', 'Borivali', 'Mira Road']

# %%
boroughs_south_mumbai = ["South Mumbai","South Mumbai","South Mumbai","South Mumbai","South Mumbai", \
             "South Mumbai","South Mumbai","South Mumbai","South Mumbai","South Mumbai", \
             "South Mumbai","South Mumbai","South Mumbai","South Mumbai","South Mumbai", \
             "South Mumbai","South Mumbai","South Mumbai","South Mumbai","South Mumbai", \
             "South Mumbai"]
#boroughs_south_mumbai  
len(boroughs_south_mumbai)
# Out:
# 21

# %%
boroughs_west_mumbai = ["West Mumbai","West Mumbai","West Mumbai","West Mumbai","West Mumbai" \
             ,"West Mumbai","West Mumbai","West Mumbai"]
             
            
#boroughs_west_mumbai

# %%
boroughs_east_mumbai = ["East Mumbai","East Mumbai","East Mumbai","East Mumbai","East Mumbai"]
boroughs_east_mumbai
# Out:
# ['East Mumbai', 'East Mumbai', 'East Mumbai', 'East Mumbai', 'East Mumbai']

# %%
boroughs_north_mumbai = ["North Mumbai","North Mumbai","North Mumbai","North Mumbai","North Mumbai"]
boroughs_north_mumbai
# Out:
# ['North Mumbai',
#  'North Mumbai',
#  'North Mumbai',
#  'North Mumbai',
#  'North Mumbai']

# %%
#boroughs = boroughs_south_mumbai + boroughs_west_mumbai + boroughs_east_mumbai + boroughs_north_mumbai
#boroughs
boroughs1 =  boroughs_south_mumbai
boroughs2 =  boroughs_west_mumbai + boroughs_east_mumbai + boroughs_north_mumbai

# %%
#areas = areas_south + areas_west + areas_east + areas_north
areas1 = areas_south
areas2 = areas_west + areas_east + areas_north

#areas

# %%
full_address1 = []
 
for area in areas1:
   
  full_address1.append(area + ", Mumbai")

# %%
full_address2 = []
 
for area in areas2:
   
  full_address2.append(area + ", Mumbai")

# %%
print("Lenght of areas1={} , boroughs1 = {} , full_address1 = {}" \
.format(len(areas1),len(boroughs1),len(full_address1)))

print("Lenght of areas2={} , boroughs2 = {} , full_address2 = {}" \
.format(len(areas2),len(boroughs2),len(full_address2)))
# Out:
# Lenght of areas1=21 , boroughs1 = 21 , full_address1 = 21
# Lenght of areas2=18 , boroughs2 = 18 , full_address2 = 18

# %%
#dic_test1 = {"Neighborhood": areas,"Boroughs": boroughs,"Address":full_address}
dic_area1 = {"Neighborhood": areas1,"Boroughs": boroughs1,"Address":full_address1}
dic_area2 = {"Neighborhood": areas2,"Boroughs": boroughs2,"Address":full_address2}
print("dic_area1:",dic_area1)
print("dic_area2:",dic_area2)
# Out:
# dic_area1: {'Neighborhood': ['Colaba', 'Apollo Bandar', 'Fort', 'Churchgate', 'Nariman Point', 'Marine Lines', 'Walkeshwar', 'Malabar Hill', 'Kalbadevi', 'Bhuleshwar', 'Masjid Bandar', 'Darukhana', 'Pydhoni', 'Nagpada', 'Dongri', 'Byculla', 'Grand Road', 'Mazgaon', 'Mumbai Central', 'Mahalaxmi', 'Worli'], 'Boroughs': ['South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai', 'South Mumbai'], 'Address': ['Colaba, Mumbai', 'Apollo Bandar, Mumbai', 'Fort, Mumbai', 'Churchgate, Mumbai', 'Nariman Point, Mumbai', 'Marine Lines, Mumbai', 'Walkeshwar, Mumbai', 'Malabar Hill, Mumbai', 'Kalbadevi, Mumbai', 'Bhuleshwar, Mumbai', 'Masjid Bandar, Mumbai', 'Darukhana, Mumbai', 'Pydhoni, Mumbai', 'Nagpada, Mumbai', 'Dongri, Mumbai', 'Byculla
# ...

# %%
df_area1 = pd.DataFrame.from_dict(dic_area1)
df_area1.head()
#df_area1.to_csv("mumbai_south_neighborhood_all.csv")
# Out:
#     Neighborhood      Boroughs                Address
# 0         Colaba  South Mumbai         Colaba, Mumbai
# 1  Apollo Bandar  South Mumbai  Apollo Bandar, Mumbai
# 2           Fort  South Mumbai           Fort, Mumbai
# 3     Churchgate  South Mumbai     Churchgate, Mumbai
# 4  Nariman Point  South Mumbai  Nariman Point, Mumbai

# %%
df_area2 = pd.DataFrame.from_dict(dic_area2)
df_area2.tail()
#df_area2.to_csv("mumbai_south_neighborhood_all.csv")
# Out:
#    Neighborhood      Boroughs             Address
# 13        Powai  North Mumbai       Powai, Mumbai
# 14   Jogeshwari  North Mumbai  Jogeshwari, Mumbai
# 15        Malad  North Mumbai       Malad, Mumbai
# 16     Borivali  North Mumbai    Borivali, Mumbai
# 17    Mira Road  North Mumbai   Mira Road, Mumbai

# %% [markdown]
# ### **Let's pass south Mumbai :  df_area1**

# %%
df2 = df_area1
df2.shape
df2.head()
# Out:
#     Neighborhood      Boroughs                Address
# 0         Colaba  South Mumbai         Colaba, Mumbai
# 1  Apollo Bandar  South Mumbai  Apollo Bandar, Mumbai
# 2           Fort  South Mumbai           Fort, Mumbai
# 3     Churchgate  South Mumbai     Churchgate, Mumbai
# 4  Nariman Point  South Mumbai  Nariman Point, Mumbai

# %%
data = []
for  neighborhood,address,borough in zip(df2['Neighborhood'], df2['Address'],df2['Boroughs']):
  #print("neighborhood:", neighborhood)
  #print("address:", address)
  geolocator = Nominatim(user_agent="ny_explorer")
  location = geolocator.geocode(address)
  latitude = location.latitude
  longitude = location.longitude
  #print("latitude:", latitude)
  #print("longitude:", longitude)
  data.append([neighborhood,borough,latitude,longitude])

col_names =  ['Neighborhood', 'Borough', 'Latitude','Longitude']
neighborhoods = pd.DataFrame(data,columns=col_names)
print("dtypes : ", neighborhoods.dtypes)
print("rows : ", neighborhoods.shape[0])
neighborhoods.head()
# Out:
# dtypes :  Neighborhood     object
# Borough          object
# Latitude        float64
# Longitude       float64
# dtype: object
# rows :  21
#     Neighborhood       Borough   Latitude  Longitude
# 0         Colaba  South Mumbai  18.915091  72.825969
# 1  Apollo Bandar  South Mumbai  18.918375  72.831443
# 2           Fort  South Mumbai  18.933266  72.834515
# 3     Churchgate  South Mumbai  18.935957  72.827340
# 4  Nariman Point  South Mumbai  18.925951  72.823208

# %%
neighborhoods1 = neighborhoods
neighborhoods1.to_csv("south_mumbai_latitudes.csv")
neighborhoods1.tail()
# Out:
#       Neighborhood       Borough   Latitude  Longitude
# 16      Grand Road  South Mumbai  18.938771  72.835335
# 17         Mazgaon  South Mumbai  18.968052  72.840012
# 18  Mumbai Central  South Mumbai  18.969586  72.819315
# 19       Mahalaxmi  South Mumbai  18.982568  72.824160
# 20           Worli  South Mumbai  19.011696  72.818070

# %% [markdown]
# ### **Now let's pass east+west+north Mumabi : df_area2**

# %%
df2 = df_area2
df2.shape
# Out:
# (18, 3)

# %%
data = []
for  neighborhood,address,borough in zip(df2['Neighborhood'], df2['Address'],df2['Boroughs']):
  print("neighborhood:", neighborhood)
  print("address:", address)
  print("borough:", borough)
  geolocator = Nominatim(user_agent="ny_explorer")
  location = geolocator.geocode(address)
  latitude = location.latitude
  longitude = location.longitude
  print("latitude:", latitude)
  print("longitude:", longitude)
  data.append([neighborhood,borough,latitude,longitude])

col_names =  ['Neighborhood', 'Borough', 'Latitude','Longitude']
neighborhoods = pd.DataFrame(data,columns=col_names)
print("dtypes : ", neighborhoods.dtypes)
print("rows : ", neighborhoods.shape[0])
#neighborhoods.head()
# Out:
# neighborhood: Dadar
# address: Dadar, Mumbai
# borough: West Mumbai
# latitude: 19.019282
# longitude: 72.8428757
# neighborhood: Bandra West
# address: Bandra West, Mumbai
# borough: West Mumbai
# latitude: 19.0583358
# longitude: 72.8302669
# neighborhood: Juhu
# address: Juhu, Mumbai
# borough: West Mumbai
# latitude: 19.1070215
# longitude: 72.8275275
# neighborhood: Andheri
# address: Andheri, Mumbai
# borough: West Mumbai
# latitude: 19.1196976
# longitude: 72.8464205
# neighborhood: Kalina
# address: Kalina, Mumbai
# borough: West Mumbai
# latitude: 19.079273
# longitude: 72.8612672
# neighborhood: Santa Cruz
# address: Santa Cruz, Mumbai
# borough: West Mumbai
# latitude: 19.0793694
# longitude: 72.8470855
# neighborhood: Mahim
# address: Mahim, Mumbai
# borough: West Mumbai
# latitude: 19.0423145
# longitude: 72.8398344
# neighborhood: Khar
# address: Khar, Mumbai
# borough: West Mumbai
# latitude: 19.0696584
# longitude: 72.8398944
# neighborhood: Kurla
# ...

# %%
neighborhoods2 = neighborhoods
neighborhoods2.shape # (19, 4)
neighborhoods2.head()
neighborhoods2.tail()
# Out:
#    Neighborhood       Borough   Latitude  Longitude
# 13        Powai  North Mumbai  19.118720  72.907348
# 14   Jogeshwari  North Mumbai  19.134899  72.848820
# 15        Malad  North Mumbai  19.186719  72.848588
# 16     Borivali  North Mumbai  19.229068  72.857363
# 17    Mira Road  North Mumbai  19.187896  72.836596

# %%
neighborhoods2.tail()
# Out:
#    Neighborhood       Borough   Latitude  Longitude
# 13        Powai  North Mumbai  19.118720  72.907348
# 14   Jogeshwari  North Mumbai  19.134899  72.848820
# 15        Malad  North Mumbai  19.186719  72.848588
# 16     Borivali  North Mumbai  19.229068  72.857363
# 17    Mira Road  North Mumbai  19.187896  72.836596

# %% [markdown]
# ## **Now Let's concat two dataframes**

# %%
neighborhoods = neighborhoods1.append(neighborhoods2,ignore_index=True)
neighborhoods.shape
#neighborhoods.head(40)
#result = df1.append(df2)
#bigdata = data1.append(data2, ignore_index=True)
# Out:
# (39, 4)

# %%
neighborhoods = neighborhoods.reset_index()

# %%
print("Merged data frame have rows.", neighborhoods.shape[0])
neighborhoods.to_csv("all_mumbai_latitude.csv")
neighborhoods.tail()
# Out:
# Merged data frame have rows. 39
#     index Neighborhood       Borough   Latitude  Longitude
# 34     34        Powai  North Mumbai  19.118720  72.907348
# 35     35   Jogeshwari  North Mumbai  19.134899  72.848820
# 36     36        Malad  North Mumbai  19.186719  72.848588
# 37     37     Borivali  North Mumbai  19.229068  72.857363
# 38     38    Mira Road  North Mumbai  19.187896  72.836596

# %%
neighborhoods.to_csv("Mumbai_locations2.csv")

# %% [markdown]
# ### Use geopy library to get the latitude and longitude values of Mumbai
# ### In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent ny_explorer, as shown below.

# %% [markdown]
# ### Create a map of Mumbai with neighborhoods superimposed on top.

# %%
# Mumbai : Latitude: 18.9600 Longitude: 72.8200
latitude = 18.9600
longitude = 72.8200
map_mumbai = folium.Map(location=[latitude, longitude], zoom_start=14)
map_mumbai
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_mumbai)  
    
map_mumbai
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'AED1YJAEJO1BSJVJJ5KT2Y2BDGDVPCB21WUXERHTA4B4XXKC' # your Foursquare ID
CLIENT_SECRET = '5WF0PKUAGWG30ASKZSBV12XHC2IDIQLEHRRPU541XI2JVQCH' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: AED1YJAEJO1BSJVJJ5KT2Y2BDGDVPCB21WUXERHTA4B4XXKC
# CLIENT_SECRET:5WF0PKUAGWG30ASKZSBV12XHC2IDIQLEHRRPU541XI2JVQCH

# %% [markdown]
# ### Let's create a function to repeat the same process to all the neighborhoods in South Mumbai

# %%
radius=650
LIMIT = 100
print("The radius is = {} and LIMIT is = {}".format(radius,LIMIT))
# Out:
# The radius is = 650 and LIMIT is = 100

# %%
LIMIT = 100
def getNearbyVenues(names, latitudes, longitudes, radius=650):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ### Now write the code to run the above function on each neighborhood and create a new dataframe called south_mumbai_venues.

# %%
south_mumbai_data = neighborhoods
#print("dtypes:",south_mumbai_data.dtypes)
#print("shape:",south_mumbai_data.shape)
#south_mumbai_data.head()

# %%
south_mumbai_venues = getNearbyVenues(names=south_mumbai_data['Neighborhood'],
                                   latitudes=south_mumbai_data['Latitude'],
                                   longitudes=south_mumbai_data['Longitude']
                                   
                                  )
print("dtypes:",south_mumbai_venues.dtypes)
print("Total venues retrieved:",south_mumbai_venues.shape[0])

#south_mumbai_venues.head()
# Out:
# Colaba
# Apollo Bandar
# Fort
# Churchgate
# Nariman Point
# Marine Lines
# Walkeshwar
# Malabar Hill
# Kalbadevi
# Bhuleshwar
# Masjid Bandar
# Darukhana
# Pydhoni
# Nagpada
# Dongri
# Byculla
# Grand Road
# Mazgaon
# Mumbai Central
# Mahalaxmi
# Worli
# Dadar
# Bandra West
# Juhu
# Andheri
# Kalina
# Santa Cruz
# Mahim
# Khar
# Kurla
# Ghatkopar
# Chembur
# Govandi
# Mulund West
# Powai
# Jogeshwari
# Malad
# Borivali
# Mira Road
# dtypes: Neighborhood               object
# Neighborhood Latitude     float64
# Neighborhood Longitude    float64
# Venue                      object
# Venue Latitude            float64
# Venue Longitude           float64
# Venue Category             object
# dtype: object
# Total venues retrieved: 1104

# %%
south_mumbai_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  ...  Venue Longitude     Venue Category
# 0       Colaba              18.915091  ...        72.824151        Men's Store
# 1       Colaba              18.915091  ...        72.827018  German Restaurant
# 2       Colaba              18.915091  ...        72.821080    Thai Restaurant
# 3       Colaba              18.915091  ...        72.829185       Dessert Shop
# 4       Colaba              18.915091  ...        72.821028              Hotel
#
# [5 rows x 7 columns]

# %% [markdown]
# # **Add Museum**

# %% [markdown]
# ### One of the key venue the biggest and most significant Museum of Mumbai not returned by Four Square API. Added this record.

# %%
south_mumbai_venues_append_test = south_mumbai_venues
south_mumbai_venues_append_test.tail()
#print("as")
south_mumbai_venues_append_test.columns
south_mumbai_venues_append_test.dtypes

south_mumbai_venues_append_test
# Out:
# index                       int64
# Neighborhood               object
# Neighborhood Latitude     float64
# Neighborhood Longitude    float64
# Venue                      object
# Venue Latitude            float64
# Venue Longitude           float64
# Venue Category             object
# dtype: object

# %%
print("row bef add:",south_mumbai_venues_append_test.shape[0])
south_mumbai_venues_append_test.append({'index':1104, \
                                        'Neighborhood': 'Apollo Bandar', \
                                        'Neighborhood Latitude':18.9183748, \
                                        'Neighborhood Longitude':72.8314429, \
                                        'Venue':'Prince Albert Museum', \
                                        'Venue Latitude':18.9269, \
                                        'Venue Longitude':72.8327, \
                                        'Venue Category':'History Museum' \
                                        },ignore_index=True)

print("row aft add:",south_mumbai_venues_append_test.shape[0])

south_mumbai_venues_append_test.tail()

#f.append({'Animal':'mouse', 'Color':'black'}, ignore_index=True)
# Out:
# row bef add: 938
# row aft add: 938
#      index Neighborhood  ...  Venue Longitude        Venue Category
# 933   1099    Mira Road  ...        72.833399                Bakery
# 934   1100    Mira Road  ...        72.835840                 Diner
# 935   1101    Mira Road  ...        72.840819        Breakfast Spot
# 936   1102    Mira Road  ...        72.842250  Fast Food Restaurant
# 937   1103    Mira Road  ...        72.841896      Department Store
#
# [5 rows x 8 columns]

# %%
south_mumbai_venues_append_test.to_csv("all_mumbai_venues_museum1.csv")

# %% [markdown]
# # Test : **Try Concat**

# %%
south_mumbai_venues_append_test.dtypes
# Out:
# index                       int64
# Neighborhood               object
# Neighborhood Latitude     float64
# Neighborhood Longitude    float64
# Venue                      object
# Venue Latitude            float64
# Venue Longitude           float64
# Venue Category             object
# dtype: object

# %%
new_record = pd.DataFrame([1104,'Apollo Bandar',18.9183748,72.8314429,\
                           'Prince Albert Museum',18.9269,72.8327,'History Museum'], \
                          columns=['index','Neighborhood','Neighborhood Latitude', \
                                      'Neighborhood Longitude','Venue','Venue Latitude','Venue Longitude','Venue Category'])
new_record.head()
#new_record = pd.DataFrame([[0,'abcd',0,1,123]],columns=['a','b','c','d','e'])
#old_data_frame = pd.concat([old_data_frame,new_record])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1653                 blocks = [
# -> 1654                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1655                 ]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3046
# -> 3047     return klass(values, ndim=ndim, placement=placement)
#    3048
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#    2594
# -> 2595         super().__init__(values, ndim=ndim, placement=placement)
#    2596
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
# ...

# %% [markdown]
# # **Drop Duplicates Venues**

# %%
duplicate1 = south_mumbai_venues
print("rows before dropping duplicates={}".format(duplicate1.shape[0]))
duplicate1 = duplicate1.drop_duplicates(subset=['Venue Latitude', 'Venue Longitude'])
print("rows after dropping duplicates={}".format(duplicate1.shape[0]))
#duplicate1.to_csv("south_mumbai_venues_no_duplicates.csv")
south_mumbai_venues.to_csv("all_mumbai_venues_650.csv")
# Out:
# rows before dropping duplicates=1104
# rows after dropping duplicates=987

# %% [markdown]
# # **Remove rows with Indian Restaurants**.

# %%
#Backup dataframe
south_mumbai_venues_bkp = south_mumbai_venues
south_mumbai_indian_restaurants = south_mumbai_venues[(south_mumbai_venues['Venue Category'] == "Indian Restaurant")]
print("mumbai indian restaurants:",south_mumbai_indian_restaurants.shape[0])  #62
south_mumbai_indian_restaurants.head()
south_mumbai_indian_restaurants.to_csv("south_mumbai_indian_restaurants.csv")

#indian_restaurants: 165
# Out:
# mumbai indian restaurants: 169

# %%
#south_mumbai_venues.dtypes
print("rows bef drop:",south_mumbai_venues.shape[0])
south_mumbai_venues = south_mumbai_venues[(south_mumbai_venues['Venue Category'] != "Indian Restaurant")].reset_index()
print("rows aft drop:",south_mumbai_venues.shape[0])
south_mumbai_venues.to_csv("south_mumbai_minus_indian_restaurants.csv")
south_mumbai_venues.head()
#1125 to 960
# Out:
# rows bef drop: 1104
# rows aft drop: 938
#    index Neighborhood  ...  Venue Longitude     Venue Category
# 0      0       Colaba  ...        72.824151        Men's Store
# 1      1       Colaba  ...        72.827018  German Restaurant
# 2      2       Colaba  ...        72.821080    Thai Restaurant
# 3      3       Colaba  ...        72.829185       Dessert Shop
# 4      4       Colaba  ...        72.821028              Hotel
#
# [5 rows x 8 columns]

# %%
south_mumbai_venues_x1 = south_mumbai_venues.groupby('Neighborhood').count()
south_mumbai_venues_x1.to_csv("all_mumbai_venues_x1_groupby.csv")

# %%
south_mumbai_venues_x1.head()
# Out:
#                index  Neighborhood Latitude  ...  Venue Longitude  Venue Category
# Neighborhood                                 ...
# Andheri           12                     12  ...               12              12
# Apollo Bandar     62                     62  ...               62              62
# Bandra West       88                     88  ...               88              88
# Bhuleshwar        17                     17  ...               17              17
# Borivali          28                     28  ...               28              28
#
# [5 rows x 7 columns]

# %%
south_mumbai_venues_categories_x2 = south_mumbai_venues.groupby('Venue Category').count()
south_mumbai_venues_categories_x2.to_csv("all_mumbai_venues_categories_x2_groupby.csv")
south_mumbai_venues_categories_x2.head()
south_mumbai_venues_categories_x2.tail()
# Out:
#                 index  Neighborhood  ...  Venue Latitude  Venue Longitude
# Venue Category                       ...
# Video Store         1             1  ...               1                1
# Wine Bar            2             2  ...               2                2
# Women's Store       4             4  ...               4                4
# Yoga Studio         1             1  ...               1                1
# Zoo                 1             1  ...               1                1
#
# [5 rows x 7 columns]

# %% [markdown]
# ## **Unique Categories**

# %%
### Let's find out how many unique categories can be curated from all the returned venues

print('There are {} uniques categories.'.format(len(south_mumbai_venues['Venue Category'].unique())))
# 158
# Out:
# There are 159 uniques categories.

# %%
### 3. Analyze Each Neighborhood

# one hot encoding
south_mumbai_onehot = pd.get_dummies(south_mumbai_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
south_mumbai_onehot['Neighborhood'] = south_mumbai_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [south_mumbai_onehot.columns[-1]] + list(south_mumbai_onehot.columns[:-1])
south_mumbai_onehot = south_mumbai_onehot[fixed_columns]

south_mumbai_onehot.head()
south_mumbai_onehot.shape
# Out:
# (1104, 157)

# %%
south_mumbai_onehot_test.to_csv("south_mumbai_onehot_test1.csv")

# %%
south_mumbai_onehot.to_csv("south_mumbai_onehot.csv")

# %%
#And let's examine the new dataframe size.
south_mumbai_onehot.shape  # (359, 105) (292,103)
# Out:
# (966, 160)

# %% [markdown]
# # **TWEAK HERE**

# %%
df_test_one_hot = pd.read_csv("south_mumbai_onehot.csv")
df_test_one_hot.shape

#df = pd.read_csv(
# Out:
# (1104, 158)

# %%
south_mumbai_grouped_test = df_test_one_hot.groupby('Neighborhood').mean().reset_index()
south_mumbai_grouped_test.shape
# Out:
# (39, 158)

# %%
south_mumbai_grouped_test.to_csv("south_mumbai_grouped_test.csv")

# %%
#Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

south_mumbai_grouped = south_mumbai_onehot.groupby('Neighborhood').mean().reset_index()
south_mumbai_grouped
# Out:
#       Neighborhood  Accessories Store  ...  Yoga Studio       Zoo
# 0          Andheri           0.000000  ...     0.000000  0.000000
# 1    Apollo Bandar           0.000000  ...     0.000000  0.000000
# 2      Bandra West           0.000000  ...     0.000000  0.000000
# 3       Bhuleshwar           0.000000  ...     0.000000  0.000000
# 4         Borivali           0.000000  ...     0.000000  0.000000
# 5          Byculla           0.000000  ...     0.000000  0.111111
# 6          Chembur           0.031250  ...     0.000000  0.000000
# 7       Churchgate           0.000000  ...     0.000000  0.000000
# 8           Colaba           0.000000  ...     0.000000  0.000000
# 9            Dadar           0.000000  ...     0.000000  0.000000
# 10       Darukhana           0.000000  ...     0.000000  0.000000
# 11          Dongri           0.000000  ...     0.000000  0.000000
# 12            Fort           0.000000  ...     0.000000  0.000000
# ...

# %%
south_mumbai_grouped.to_csv("south_mumbai_grouped.csv")

# %%
south_mumbai_grouped.to_csv("south_mumbai_grouped.csv")

# %%
south_mumbai_grouped.shape #(21, 105)->(21,103)
# Out:
# (21, 121)

# %%
## Let's print each neighborhood along with the top 5 most common venues

num_top_venues = 5

for hood in south_mumbai_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = south_mumbai_grouped[south_mumbai_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Andheri----
#                   venue  freq
# 0  Fast Food Restaurant  0.25
# 1            Restaurant  0.17
# 2             Bookstore  0.08
# 3                Bakery  0.08
# 4            Food Court  0.08
#
#
# ----Apollo Bandar----
#          venue  freq
# 0        Hotel  0.13
# 1         Café  0.08
# 2          Bar  0.08
# 3  Coffee Shop  0.05
# 4   Restaurant  0.05
#
#
# ----Bandra West----
#                 venue  freq
# 0                Café  0.10
# 1                 Bar  0.07
# 2              Bakery  0.07
# 3    Asian Restaurant  0.05
# 4  Chinese Restaurant  0.05
#
#
# ----Bhuleshwar----
#             venue  freq
# 0  Ice Cream Shop  0.12
# 1           Hotel  0.06
# 2       BBQ Joint  0.06
# 3     Snack Place  0.06
# 4            Café  0.06
#
#
# ----Borivali----
#                            venue  freq
# 0                 Ice Cream Shop  0.11
# 1                 Clothing Store  0.11
# 2             Chinese Restaurant  0.11
# 3  Vegetarian / Vegan Restaurant  0.07
# ...

# %%
#Let's put that into a pandas dataframe
#First, let's write a function to sort the venues in descending orde

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
#Now let's create the new dataframe and display the top 10 venues for each neighborhood.

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = south_mumbai_grouped['Neighborhood']

for ind in np.arange(south_mumbai_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(south_mumbai_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#     Neighborhood  ... 10th Most Common Venue
# 0        Andheri  ...                    Zoo
# 1  Apollo Bandar  ...    Japanese Restaurant
# 2    Bandra West  ...            Pizza Place
# 3     Bhuleshwar  ...              BBQ Joint
# 4       Borivali  ...         Breakfast Spot
#
# [5 rows x 11 columns]

# %%
neighborhoods_venues_sorted.to_csv("south_mumbai_top10_venue_categories_minus_indian_rest.csv")

# %% [markdown]
# # **Cluster Neighborhood**

# %% [markdown]
# ## **Run k-means. Adjust number of clusters to optimum.**

# %%
# Run k-means to cluster the neighborhood into 5 clusters.
# Try with more clusters and see results.
# set number of clusters
#kclusters = 5 # First Iteration
#kclusters = 10 # Second Iteration
#kclusters = 5 # Third Iteration after removing Indian restaurants
kclusters = 10 # Fourth Iteration after removing Indian restaurants

# %%
# 4. Cluster Neighborhoods
south_mumbai_grouped_clustering = south_mumbai_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(south_mumbai_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 4, 6, 1, 6, 5, 6, 1, 4, 1], dtype=int32)

# %%
### Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
neighborhoods_venues_sorted.dtypes
# Out:
# Cluster Labels             int32
# Neighborhood              object
# 1st Most Common Venue     object
# 2nd Most Common Venue     object
# 3rd Most Common Venue     object
# 4th Most Common Venue     object
# 5th Most Common Venue     object
# 6th Most Common Venue     object
# 7th Most Common Venue     object
# 8th Most Common Venue     object
# 9th Most Common Venue     object
# 10th Most Common Venue    object
# dtype: object

# %%
### Now merge both dataframes

south_mumbai_merged = south_mumbai_data

# merge two dataframes
south_mumbai_merged = south_mumbai_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

south_mumbai_merged.head() 
# check 'Cluster Labels' column has been added to dataframe
# Out:
#    index   Neighborhood  ... 9th Most Common Venue    10th Most Common Venue
# 0      0         Colaba  ...   Japanese Restaurant                       Pub
# 1      1  Apollo Bandar  ...          Cocktail Bar       Japanese Restaurant
# 2      2           Fort  ...      Parsi Restaurant                     Plaza
# 3      3     Churchgate  ...         Movie Theater               Pizza Place
# 4      4  Nariman Point  ...                 Diner  Mediterranean Restaurant
#
# [5 rows x 16 columns]

# %% [markdown]
# # **Drop rows with missing data**

# %%
#df.dropna(subset = ['column1_name', 'column2_name', 'column3_name'])
print("rows bef:",south_mumbai_merged.shape[0])
south_mumbai_merged.dropna()
print("rows aft:",south_mumbai_merged.shape[0])
# Out:
# rows bef: 39
# rows aft: 39

# %% [markdown]
# #### No row with any missing data found.

# %%
#south_mumbai_merged.dtypes #Cluster Labels float64
#south_mumbai_merged[["Cluster Labels"]] = south_mumbai_merged[["Cluster Labels"]].astype(int)
south_mumbai_merged.dtypes
# Out:
# index                       int64
# Neighborhood               object
# Borough                    object
# Latitude                  float64
# Longitude                 float64
# Cluster Labels              int32
# 1st Most Common Venue      object
# 2nd Most Common Venue      object
# 3rd Most Common Venue      object
# 4th Most Common Venue      object
# 5th Most Common Venue      object
# 6th Most Common Venue      object
# 7th Most Common Venue      object
# 8th Most Common Venue      object
# 9th Most Common Venue      object
# 10th Most Common Venue     object
# dtype: object

# %%
south_mumbai_merged.to_csv("all_mumbai_cluster_k10_r650.csv")

# %%
#Finally, let's visualize the resulting clusters
#South Mumbai Latitude: 18.9600 Longitude: 72.8200
latitude  = 18.9600
longitude = 72.8200

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(south_mumbai_merged['Latitude'], south_mumbai_merged['Longitude'], south_mumbai_merged['Neighborhood'], south_mumbai_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # **This concludes the iteration No . Thank You.**

# %%
print("147KK")
# Out:
# 147KK
